# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r"C:\Users\devso\causal-ml-project\data\raw\hillstrom.csv")

# treatment
df['treatment'] = df['segment'].apply(lambda x: 0 if x == 'No E-Mail' else 1)

# remove leakage
df = df.drop(columns=['segment', 'visit', 'spend'])

# encoding
df = pd.get_dummies(df, drop_first=True)

# define variables
X = df.drop(columns=['conversion', 'treatment'])
T = df['treatment']
Y = df['conversion']

# %%
#S-LEARNER
from sklearn.linear_model import LogisticRegression

# combine X + treatment
X_s = X.copy()
X_s['treatment'] = T

model_s = LogisticRegression(max_iter=1000)
model_s.fit(X_s, Y)
# Out:
# LogisticRegression(max_iter=1000)

# %%
#Estimate ITE
# predict with treatment = 1
X_treated = X.copy()
X_treated['treatment'] = 1

# predict with treatment = 0
X_control = X.copy()
X_control['treatment'] = 0

y1 = model_s.predict_proba(X_treated)[:,1]
y0 = model_s.predict_proba(X_control)[:,1]

ite_s = y1 - y0

df['ITE_S'] = ite_s

# %%
#T-LEARNER
# split data
X_t = X[T == 1]
Y_t = Y[T == 1]

X_c = X[T == 0]
Y_c = Y[T == 0]

# models
model_t = LogisticRegression(max_iter=1000)
model_c = LogisticRegression(max_iter=1000)

model_t.fit(X_t, Y_t)
model_c.fit(X_c, Y_c)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y1_t = model_t.predict_proba(X)[:,1]
y0_t = model_c.predict_proba(X)[:,1]

ite_t = y1_t - y0_t

df['ITE_T'] = ite_t

# %%
import matplotlib.pyplot as plt

plt.hist(df['ITE_T'], bins=50)
plt.title("Distribution of Individual Treatment Effects (T-Learner)")
plt.show()

# %%
# top users who benefit most
df.sort_values(by='ITE_T', ascending=False).head(10)
# Out:
#        recency  history  mens  womens  newbie  conversion  treatment  \
# 29246        1   990.78     1       1       1           0          0
# 13103        1   966.76     1       1       1           0          1
# 44831        1   937.28     1       1       1           0          0
# 53740        1   930.77     1       1       1           0          0
# 56582        1   926.25     1       1       1           0          1
# 12746        2   952.61     1       1       1           0          0
# 44864        1   785.85     1       1       1           0          0
# 55519        1   766.19     1       1       1           0          0
# 18483        2   846.69     1       1       1           0          0
# 19674        1   751.80     1       1       1           0          0
#
#        history_segment_2) $100 - $200  history_segment_3) $200 - $350  \
# 29246                           False                           False
# ...

# %%
print("ATE from T-Learner:", df['ITE_T'].mean())
# Out:
# ATE from T-Learner: 0.005011549758741804
